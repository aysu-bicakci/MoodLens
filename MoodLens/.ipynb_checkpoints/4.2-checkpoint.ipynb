# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# Veri yollarını tanımlayalım
train_dir = "C:\\Users\\Yusuf\\source\\jupyter\\dl\\images\\train"
validation_dir = "C:\\Users\\Yusuf\\source\\jupyter\\dl\\images\\validation"
train_happy_dir = os.path.join(train_dir, 'happy')
train_sad_dir = os.path.join(train_dir, 'sad')
validation_happy_dir = os.path.join(validation_dir, 'happy')
validation_sad_dir = os.path.join(validation_dir, 'sad')

# %%
# Veri artırma ve ölçekleme
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(48, 48),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 12102 images belonging to 2 classes.
# Found 2964 images belonging to 2 classes.

# %%
# CNN modeli oluşturalım
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dropout(0.5),  # Dropout ekleyelim
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# Modeli eğitelim
history_dropout = model.fit(
    train_generator,
    steps_per_epoch=200,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=50
)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 22s 109ms/step - loss: 0.6774 - accuracy: 0.5916 - val_loss: 0.6681 - val_accuracy: 0.6313
# Epoch 2/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.6568 - accuracy: 0.6109 - val_loss: 0.6272 - val_accuracy: 0.6625
# Epoch 3/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.6444 - accuracy: 0.6308 - val_loss: 0.6242 - val_accuracy: 0.6544
# Epoch 4/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.6251 - accuracy: 0.6480 - val_loss: 0.6175 - val_accuracy: 0.6562
# Epoch 5/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.5970 - accuracy: 0.6672 - val_loss: 0.5233 - val_accuracy: 0.7256
# Epoch 6/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.5084 - accuracy: 0.7414 - val_loss: 0.4427 - val_accuracy: 0.7956
# Epoch 7/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4380 - accuracy: 0.7874 - val_loss: 0.4508 - val_accuracy: 0.7850
# Epoch 8/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.4014 - accuracy: 0.8127 - val_loss: 0.3840 - val_accuracy: 0.8163
# Epoch 9/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.3773 - accuracy: 0.8241 - val_loss: 0.3729 - val_accuracy: 0.8288
# Epoch 10/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.3554 - accuracy: 0.8340 - val_loss: 0.3709 - val_accuracy: 0.8381
# Epoch 11/50
# 200/200 [==============================] - 22s 107ms/step - loss: 0.3339 - accuracy: 0.8516 - val_loss: 0.3418 - val_accuracy: 0.8531
# Epoch 12/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.3149 - accuracy: 0.8583 - val_loss: 0.3607 - val_accuracy: 0.8356
# Epoch 13/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.3104 - accuracy: 0.8600 - val_loss: 0.3275 - val_accuracy: 0.8619
# Epoch 14/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.2872 - accuracy: 0.8702 - val_loss: 0.3324 - val_accuracy: 0.8619
# Epoch 15/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.2852 - accuracy: 0.8698 - val_loss: 0.3573 - val_accuracy: 0.8462
# Epoch 16/50
# 200/200 [==============================] - 22s 107ms/step - loss: 0.2644 - accuracy: 0.8834 - val_loss: 0.3140 - val_accuracy: 0.8575
# Epoch 17/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.2590 - accuracy: 0.8866 - val_loss: 0.3248 - val_accuracy: 0.8594
# Epoch 18/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.2426 - accuracy: 0.8953 - val_loss: 0.3210 - val_accuracy: 0.8550
# Epoch 19/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.2412 - accuracy: 0.8971 - val_loss: 0.3297 - val_accuracy: 0.8587
# Epoch 20/50
# 200/200 [==============================] - 22s 107ms/step - loss: 0.2271 - accuracy: 0.9031 - val_loss: 0.3355 - val_accuracy: 0.8694
# Epoch 21/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.2157 - accuracy: 0.9137 - val_loss: 0.3181 - val_accuracy: 0.8625
# Epoch 22/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.2099 - accuracy: 0.9093 - val_loss: 0.3259 - val_accuracy: 0.8650
# Epoch 23/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1953 - accuracy: 0.9205 - val_loss: 0.3293 - val_accuracy: 0.8744
# Epoch 24/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1818 - accuracy: 0.9253 - val_loss: 0.3635 - val_accuracy: 0.8587
# Epoch 25/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1788 - accuracy: 0.9248 - val_loss: 0.3798 - val_accuracy: 0.8644
# Epoch 26/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1758 - accuracy: 0.9275 - val_loss: 0.3173 - val_accuracy: 0.8712
# Epoch 27/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.1646 - accuracy: 0.9341 - val_loss: 0.3847 - val_accuracy: 0.8587
# Epoch 28/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1609 - accuracy: 0.9344 - val_loss: 0.3411 - val_accuracy: 0.8769
# Epoch 29/50
# 200/200 [==============================] - 22s 109ms/step - loss: 0.1587 - accuracy: 0.9338 - val_loss: 0.3796 - val_accuracy: 0.8650
# Epoch 30/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1409 - accuracy: 0.9409 - val_loss: 0.3492 - val_accuracy: 0.8612
# Epoch 31/50
# 200/200 [==============================] - 22s 109ms/step - loss: 0.1396 - accuracy: 0.9430 - val_loss: 0.4005 - val_accuracy: 0.8737
# Epoch 32/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1291 - accuracy: 0.9500 - val_loss: 0.4209 - val_accuracy: 0.8606
# Epoch 33/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.1251 - accuracy: 0.9520 - val_loss: 0.3900 - val_accuracy: 0.8675
# Epoch 34/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1230 - accuracy: 0.9498 - val_loss: 0.4040 - val_accuracy: 0.8562
# Epoch 35/50
# 200/200 [==============================] - 22s 109ms/step - loss: 0.1160 - accuracy: 0.9569 - val_loss: 0.4409 - val_accuracy: 0.8650
# Epoch 36/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1070 - accuracy: 0.9588 - val_loss: 0.3725 - val_accuracy: 0.8800
# Epoch 37/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1009 - accuracy: 0.9620 - val_loss: 0.4167 - val_accuracy: 0.8737
# Epoch 38/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.1025 - accuracy: 0.9588 - val_loss: 0.4629 - val_accuracy: 0.8600
# Epoch 39/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.1005 - accuracy: 0.9614 - val_loss: 0.4506 - val_accuracy: 0.8631
# Epoch 40/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.0898 - accuracy: 0.9655 - val_loss: 0.4238 - val_accuracy: 0.8744
# Epoch 41/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.1015 - accuracy: 0.9619 - val_loss: 0.4295 - val_accuracy: 0.8644
# Epoch 42/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.0890 - accuracy: 0.9645 - val_loss: 0.4193 - val_accuracy: 0.8669
# Epoch 43/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.0922 - accuracy: 0.9631 - val_loss: 0.4358 - val_accuracy: 0.8719
# Epoch 44/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.0787 - accuracy: 0.9691 - val_loss: 0.5488 - val_accuracy: 0.8619
# Epoch 45/50
# 200/200 [==============================] - 21s 107ms/step - loss: 0.0818 - accuracy: 0.9682 - val_loss: 0.4836 - val_accuracy: 0.8700
# Epoch 46/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.0792 - accuracy: 0.9699 - val_loss: 0.5686 - val_accuracy: 0.8612
# Epoch 47/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.0811 - accuracy: 0.9698 - val_loss: 0.4206 - val_accuracy: 0.8725
# Epoch 48/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.0737 - accuracy: 0.9716 - val_loss: 0.4548 - val_accuracy: 0.8737
# Epoch 49/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.0697 - accuracy: 0.9727 - val_loss: 0.5502 - val_accuracy: 0.8637
# Epoch 50/50
# 200/200 [==============================] - 22s 108ms/step - loss: 0.0683 - accuracy: 0.9737 - val_loss: 0.4787 - val_accuracy: 0.8669

# %%
# Sonuçları çizdirelim
train_acc_dropout = history_dropout.history['accuracy']
val_acc_dropout = history_dropout.history['val_accuracy']
epochs_dropout = range(1, len(train_acc_dropout) + 1)

plt.plot(epochs_dropout, train_acc_dropout, 'bo', label='Training accuracy with Dropout')
plt.plot(epochs_dropout, val_acc_dropout, 'b', label='Validation accuracy with Dropout')
plt.title('Training and validation accuracy with Dropout')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Modeli kaydedelim
model.save('model_dropout.h5')
